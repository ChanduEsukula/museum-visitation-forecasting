# %% [markdown]
# # Feature Engineering Review
#
# This placeholder notebook summarizes the feature engineering lane for the portfolio version of the project.
#
# Key feature groups include lagged visitation, rolling visitor averages, weather aggregates, calendar/seasonality indicators, and Google Trends search-interest columns. The final merged datasets are stored under `data/processed/`.
