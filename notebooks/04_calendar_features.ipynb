# %% [markdown]
# # Calendar and Seasonality Features
#
# This placeholder notebook documents the calendar feature lane for the portfolio version of the project. Calendar outputs used by the model are stored in `data/processed/calendar_monthly.csv` and `data/processed/calendar_seasonality.csv`.
#
# The public README summarizes the feature groups and modeling workflow.
